# %%
import numpy as np
from PIL import ImageGrab
import cv2
import time
import pyautogui

# %%
# for x in range(50):
#     print ("Up")
#     pyautogui.press('up')
# for i in list(range(5))[::-1]:
#     print (i+1)
#     time.sleep(1)

# screen =  np.array(ImageGrab.grab(bbox=(570, 360, 1330, 499)))
# np.save("gameover",screen)

# pyautogui.keyDown("up")



# last_time = time.time()
while(True):
    oldScreen =  np.array(ImageGrab.grab(bbox=(570, 360, 1330, 499)))
    cv2.imshow('window',oldScreen)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
    newScreen =  np.array(ImageGrab.grab(bbox=(570, 360, 1330, 499)))
    if (newScreen == oldScreen).all():
        print ("Game Over.")
    else:
#         print ("NOT Game Over.")
#     print ("Loop took {}".format(time.time()-last_time))
#     last_time = time.time()
# Out:
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# NOT Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
# Game Over.
